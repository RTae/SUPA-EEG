# %%
from src.object_classification import load_data
from omegaconf import OmegaConf
from utilities import get_device

# %%
cfg = OmegaConf.load("./params.yaml")
device = get_device()

# %%
data = load_data(cfg, device)
# Out:
# 2026-04-22 18:23:28.478 | INFO     | src.dataset:__init__:94 - data_path=data/EEG-ImageNet.pth  device=cpu  granularity=fine  subject=0
# 2026-04-22 18:23:37.321 | INFO     | src.object_classification:_prep_time_features:55 - Using raw time-domain features for the dataset.
